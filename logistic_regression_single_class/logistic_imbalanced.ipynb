# %%
from sklearn.datasets import make_classification
from collections import Counter
import pandas as pd

# %%
X, y = make_classification(n_samples=10000, n_features=2, n_classes=2, n_clusters_per_class=1, weights=[0.99],random_state=0, n_informative=2, n_redundant=0)

# %%
Counter(y)
# Out:
# Counter({0: 9847, 1: 153})

# %%
pd.DataFrame(X)[0]
# Out:
# 0       1.474533
# 1       1.284699
# 2       1.971417
# 3       0.724362
# 4       0.899841
#           ...
# 9995    0.885387
# 9996    1.067920
# 9997    0.503649
# 9998    0.866827
# 9999    1.667061
# Name: 0, Length: 10000, dtype: float64

# %%
## Visualize the dataset
import pandas as pd
import seaborn as sns
sns.scatterplot(x = pd.DataFrame(X)[0], y = pd.DataFrame(X)[1], hue=y)
# Out:
# <Axes: xlabel='0', ylabel='1'>

# %%
## Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=10)

# %%
## Train the model
from sklearn.linear_model import LogisticRegression
class_weight = [{0: w, 1:y} for w in [1, 10, 50, 100] for y in [1, 10, 50, 100]]

# %%
penalty = ['l1', 'l2', 'elasticnet']
c = [100, 10.0, 0.01, 0.001]
random_state = 42
solver = ['lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga']

# %%
params = dict(
    penalty = penalty,
    C = c,
    solver = solver,
    class_weight = class_weight
)

logs = LogisticRegression()

# %%
## hyper paramter turning
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
cv = StratifiedKFold()
grid = GridSearchCV(estimator = logs, param_grid = params, n_jobs=-1, scoring='accuracy', cv=cv)

# %%
grid.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
y_pred = grid.predict(X_test)

# %%
grid.best_score_
# Out:
# 0.990875

# %%
grid.best_estimator_
# Out:
# LogisticRegression(C=100, class_weight={0: 10, 1: 50}, penalty='l1',
#                    solver='liblinear')

# %%
from sklearn.model_selection import RandomizedSearchCV
random = RandomizedSearchCV(estimator = logs, param_distributions= params, n_jobs=-1, scoring='accuracy', cv=cv)

# %%
random.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
random.best_score_
# Out:
# 0.99025
